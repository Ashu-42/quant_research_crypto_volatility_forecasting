# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashu-42/quant_research_crypto_volatility_forecasting/blob/quant_DL_ashu/notebooks/05_GRU_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from pathlib import Path

import json
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.layers import (
    Input,
    GRU,
    Dense,
    Dropout,
)
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
)

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

try:
    tf.config.experimental.enable_op_determinism()
except Exception:
    pass

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %%
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
LOOKBACK_DAYS = 30

# %%
shared_project_dir = Path(
    "/content/drive/MyDrive/Quant Research"
)

btc_data_dir = (
    shared_project_dir
    / "data"
    / "model_ready"
    / "BTCUSDT"
    / f"lookback_{LOOKBACK_DAYS}d"
)

results_dir = (
    shared_project_dir
    / "results"
    / "BTCUSDT"
    / f"lookback_{LOOKBACK_DAYS}d"
    / "GRU"
)

models_dir = (
    shared_project_dir
    / "models"
    / "BTCUSDT"
    / f"lookback_{LOOKBACK_DAYS}d"
    / "GRU"
)

results_dir.mkdir(
    parents=True,
    exist_ok=True
)

models_dir.mkdir(
    parents=True,
    exist_ok=True
)

# %%
X_train = np.load(
    btc_data_dir / "X_train_scaled.npy"
)

X_val = np.load(
    btc_data_dir / "X_val_scaled.npy"
)

y_train = np.load(
    btc_data_dir / "y_train.npy"
)

y_val = np.load(
    btc_data_dir / "y_val.npy"
)

validation_metadata = pd.read_parquet(
    btc_data_dir
    / "validation_metadata.parquet"
)

with open(
    btc_data_dir / "dataset_configuration.json",
    "r",
    encoding="utf-8"
) as file:
    configuration = json.load(file)

# %%
print("X_train:", X_train.shape)
print("X_val:", X_val.shape)
print("y_train:", y_train.shape)
print("y_val:", y_val.shape)

assert X_train.shape[0] == y_train.shape[0]
assert X_val.shape[0] == y_val.shape[0]
assert X_train.shape[1:] == X_val.shape[1:]
assert len(validation_metadata) == len(y_val)
# Out:
# X_train: (1303, 30, 7)
# X_val: (365, 30, 7)
# y_train: (1303,)
# y_val: (365,)

# %%
def build_gru_model(
    lookback_days,
    n_features
):
    model = Sequential(
        [
            Input(
                shape=(
                    lookback_days,
                    n_features
                )
            ),

            GRU(
                units=32,
                activation="tanh",
                recurrent_activation="sigmoid",
                return_sequences=False,
                dropout=0.0,
                recurrent_dropout=0.0,
            ),

            Dropout(rate=0.20),

            Dense(
                units=16,
                activation="relu"
            ),

            Dropout(rate=0.10),

            Dense(
                units=1,
                activation="linear"
            ),
        ],
        name="btc_gru_log_rv"
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=0.001
        ),
        loss="mse",
        metrics=[
            tf.keras.metrics.MeanAbsoluteError(
                name="mae"
            )
        ]
    )

    return model

# %%
LOOKBACK_DAYS = X_train.shape[1]
N_FEATURES = X_train.shape[2]

gru_model = build_gru_model(
    lookback_days=LOOKBACK_DAYS,
    n_features=N_FEATURES
)

gru_model.summary()
# Out:
# Model: "btc_gru_log_rv"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 32)             │         3,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,481 (17.50 KB)
#  Trainable params: 4,481 (17.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
best_model_path = (
    models_dir
    / "best_gru_model.keras"
)

callbacks = [
    EarlyStopping(
        monitor="val_loss",
        patience=15,
        restore_best_weights=True,
        min_delta=1e-4,
        verbose=1
    ),

    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),

    ModelCheckpoint(
        filepath=best_model_path,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    ),
]

# %%
history = gru_model.fit(
    X_train,
    y_train,
    validation_data=(
        X_val,
        y_val
    ),
    epochs=200,
    batch_size=32,
    shuffle=False,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 54.5813 - mae: 7.2820
# Epoch 1: val_loss improved from None to 53.01724, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 58.1161 - mae: 7.5261 - val_loss: 53.0172 - val_mae: 7.2301 - learning_rate: 0.0010
# Epoch 2/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 44.8130 - mae: 6.5861
# Epoch 2: val_loss improved from 53.01724 to 35.66613, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 46.8676 - mae: 6.7447 - val_loss: 35.6661 - val_mae: 5.9147 - learning_rate: 0.0010
# Epoch 3/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 17.8326 - mae: 3.8611
# Epoch 3: val_loss improved from 35.66613 to 0.73486, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 11.2003 - mae: 2.8026 - val_loss: 0.7349 - val_mae: 0.6803 - learning_rate: 0.0010
# Epoch 4/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.9729 - mae: 1.5955
# Epoch 4: val_loss improved from 0.73486 to 0.65072, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.4642 - mae: 1.4721 - val_loss: 0.6507 - val_mae: 0.6101 - learning_rate: 0.0010
# Epoch 5/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.0224 - mae: 1.3900
# Epoch 5: val_loss improved from 0.65072 to 0.64209, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.9336 - mae: 1.3577 - val_loss: 0.6421 - val_mae: 0.6241 - learning_rate: 0.0010
# Epoch 6/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6925 - mae: 1.2900
# Epoch 6: val_loss improved from 0.64209 to 0.63815, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.7630 - mae: 1.3029 - val_loss: 0.6381 - val_mae: 0.6259 - learning_rate: 0.0010
# Epoch 7/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6609 - mae: 1.3107
# Epoch 7: val_loss did not improve from 0.63815
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.9042 - mae: 1.3285 - val_loss: 0.6484 - val_mae: 0.6411 - learning_rate: 0.0010
# Epoch 8/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.7289 - mae: 1.2890
# Epoch 8: val_loss did not improve from 0.63815
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.9261 - mae: 1.3384 - val_loss: 0.6694 - val_mae: 0.6577 - learning_rate: 0.0010
# Epoch 9/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6100 - mae: 1.2936
# Epoch 9: val_loss did not improve from 0.63815
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.6388 - mae: 1.2746 - val_loss: 0.6540 - val_mae: 0.6487 - learning_rate: 0.0010
# Epoch 10/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5724 - mae: 1.2719
# Epoch 10: val_loss did not improve from 0.63815
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.8128 - mae: 1.3200 - val_loss: 0.6899 - val_mae: 0.6735 - learning_rate: 0.0010
# Epoch 11/200
# 38/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3774 - mae: 1.2289
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_loss did not improve from 0.63815
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3911 - mae: 1.2224 - val_loss: 0.6753 - val_mae: 0.6662 - learning_rate: 0.0010
# Epoch 12/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5828 - mae: 1.2739
# Epoch 12: val_loss improved from 0.63815 to 0.61644, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.6187 - mae: 1.2681 - val_loss: 0.6164 - val_mae: 0.6227 - learning_rate: 5.0000e-04
# Epoch 13/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3228 - mae: 1.2148
# Epoch 13: val_loss improved from 0.61644 to 0.59949, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.3160 - mae: 1.2081 - val_loss: 0.5995 - val_mae: 0.6059 - learning_rate: 5.0000e-04
# Epoch 14/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.2992 - mae: 1.1869
# Epoch 14: val_loss improved from 0.59949 to 0.59705, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 2.4364 - mae: 1.2274 - val_loss: 0.5970 - val_mae: 0.6048 - learning_rate: 5.0000e-04
# Epoch 15/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.1198 - mae: 1.1554
# Epoch 15: val_loss improved from 0.59705 to 0.59393, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 2.2251 - mae: 1.1785 - val_loss: 0.5939 - val_mae: 0.5994 - learning_rate: 5.0000e-04
# Epoch 16/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1643 - mae: 1.1517
# Epoch 16: val_loss did not improve from 0.59393
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3394 - mae: 1.2131 - val_loss: 0.5968 - val_mae: 0.6064 - learning_rate: 5.0000e-04
# Epoch 17/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2385 - mae: 1.1957
# Epoch 17: val_loss did not improve from 0.59393
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3441 - mae: 1.2227 - val_loss: 0.5972 - val_mae: 0.6077 - learning_rate: 5.0000e-04
# Epoch 18/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7956 - mae: 1.0697
# Epoch 18: val_loss did not improve from 0.59393
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0803 - mae: 1.1433 - val_loss: 0.6021 - val_mae: 0.6129 - learning_rate: 5.0000e-04
# Epoch 19/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2416 - mae: 1.1918
# Epoch 19: val_loss did not improve from 0.59393
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3217 - mae: 1.2044 - val_loss: 0.6137 - val_mae: 0.6235 - learning_rate: 5.0000e-04
# Epoch 20/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1369 - mae: 1.1747
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 20: val_loss did not improve from 0.59393
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2159 - mae: 1.1790 - val_loss: 0.6016 - val_mae: 0.6126 - learning_rate: 5.0000e-04
# Epoch 21/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1699 - mae: 1.1578
# Epoch 21: val_loss improved from 0.59393 to 0.59162, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 21: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.2306 - mae: 1.1661 - val_loss: 0.5916 - val_mae: 0.6014 - learning_rate: 2.5000e-04
# Epoch 22/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9996 - mae: 1.1293
# Epoch 22: val_loss did not improve from 0.59162
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1034 - mae: 1.1413 - val_loss: 0.5925 - val_mae: 0.6040 - learning_rate: 2.5000e-04
# Epoch 23/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1394 - mae: 1.1380
# Epoch 23: val_loss improved from 0.59162 to 0.59018, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 23: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1895 - mae: 1.1554 - val_loss: 0.5902 - val_mae: 0.5999 - learning_rate: 2.5000e-04
# Epoch 24/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.7714 - mae: 1.0641
# Epoch 24: val_loss did not improve from 0.59018
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0255 - mae: 1.1323 - val_loss: 0.5904 - val_mae: 0.5981 - learning_rate: 2.5000e-04
# Epoch 25/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9140 - mae: 1.0775
# Epoch 25: val_loss did not improve from 0.59018
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1690 - mae: 1.1385 - val_loss: 0.5910 - val_mae: 0.5958 - learning_rate: 2.5000e-04
# Epoch 26/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1647 - mae: 1.1743
# Epoch 26: val_loss improved from 0.59018 to 0.58974, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 26: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.2607 - mae: 1.1915 - val_loss: 0.5897 - val_mae: 0.5983 - learning_rate: 2.5000e-04
# Epoch 27/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.8922 - mae: 1.0942
# Epoch 27: val_loss improved from 0.58974 to 0.58951, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 27: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.0543 - mae: 1.1524 - val_loss: 0.5895 - val_mae: 0.5957 - learning_rate: 2.5000e-04
# Epoch 28/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.0189 - mae: 1.1129
# Epoch 28: val_loss improved from 0.58951 to 0.58925, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 28: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 2.1424 - mae: 1.1535 - val_loss: 0.5892 - val_mae: 0.6022 - learning_rate: 2.5000e-04
# Epoch 29/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.8701 - mae: 1.0479
# Epoch 29: val_loss did not improve from 0.58925
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 2.2046 - mae: 1.1370 - val_loss: 0.5927 - val_mae: 0.6077 - learning_rate: 2.5000e-04
# Epoch 30/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.9345 - mae: 1.0964
# Epoch 30: val_loss did not improve from 0.58925
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.0525 - mae: 1.1292 - val_loss: 0.5977 - val_mae: 0.5947 - learning_rate: 2.5000e-04
# Epoch 31/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1139 - mae: 1.1566
# Epoch 31: val_loss improved from 0.58925 to 0.58650, saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
#
# Epoch 31: finished saving model to /content/drive/MyDrive/Quant Research/models/BTCUSDT/lookback_30d/GRU/best_gru_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1950 - mae: 1.1701 - val_loss: 0.5865 - val_mae: 0.5952 - learning_rate: 2.5000e-04
# Epoch 32/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0326 - mae: 1.1059
# Epoch 32: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1515 - mae: 1.1381 - val_loss: 0.5873 - val_mae: 0.5956 - learning_rate: 2.5000e-04
# Epoch 33/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0115 - mae: 1.1201
# Epoch 33: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0997 - mae: 1.1394 - val_loss: 0.5881 - val_mae: 0.5975 - learning_rate: 2.5000e-04
# Epoch 34/200
# 38/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0160 - mae: 1.1246
# Epoch 34: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1958 - mae: 1.1607 - val_loss: 0.5935 - val_mae: 0.5947 - learning_rate: 2.5000e-04
# Epoch 35/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8955 - mae: 1.0779
# Epoch 35: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0877 - mae: 1.1380 - val_loss: 0.5877 - val_mae: 0.5946 - learning_rate: 2.5000e-04
# Epoch 36/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8304 - mae: 1.0782
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 36: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9824 - mae: 1.1199 - val_loss: 0.5885 - val_mae: 0.5950 - learning_rate: 2.5000e-04
# Epoch 37/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7480 - mae: 1.0456
# Epoch 37: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9837 - mae: 1.1009 - val_loss: 0.5939 - val_mae: 0.5949 - learning_rate: 1.2500e-04
# Epoch 38/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9708 - mae: 1.1027
# Epoch 38: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1061 - mae: 1.1420 - val_loss: 0.5983 - val_mae: 0.5959 - learning_rate: 1.2500e-04
# Epoch 39/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0524 - mae: 1.1453
# Epoch 39: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2354 - mae: 1.1846 - val_loss: 0.5966 - val_mae: 0.5951 - learning_rate: 1.2500e-04
# Epoch 40/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8784 - mae: 1.0752
# Epoch 40: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0707 - mae: 1.1247 - val_loss: 0.5951 - val_mae: 0.5947 - learning_rate: 1.2500e-04
# Epoch 41/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8323 - mae: 1.0715
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 41: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9230 - mae: 1.0996 - val_loss: 0.5986 - val_mae: 0.5954 - learning_rate: 1.2500e-04
# Epoch 42/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.8704 - mae: 1.0706
# Epoch 42: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 2.0555 - mae: 1.1202 - val_loss: 0.5989 - val_mae: 0.5954 - learning_rate: 6.2500e-05
# Epoch 43/200
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.8420 - mae: 1.0718
# Epoch 43: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.9912 - mae: 1.1184 - val_loss: 0.5948 - val_mae: 0.5944 - learning_rate: 6.2500e-05
# Epoch 44/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.0817 - mae: 1.1578
# Epoch 44: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.1293 - mae: 1.1551 - val_loss: 0.5954 - val_mae: 0.5945 - learning_rate: 6.2500e-05
# Epoch 45/200
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.9260 - mae: 1.0858
# Epoch 45: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 2.0376 - mae: 1.1175 - val_loss: 0.5933 - val_mae: 0.5941 - learning_rate: 6.2500e-05
# Epoch 46/200
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9403 - mae: 1.0841
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 46: val_loss did not improve from 0.58650
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0826 - mae: 1.1377 - val_loss: 0.5933 - val_mae: 0.5940 - learning_rate: 6.2500e-05
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 31.

# %%
history_df = pd.DataFrame(
    history.history
)

history_df["epoch"] = (
    np.arange(len(history_df)) + 1
)

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    history_df["epoch"],
    history_df["loss"],
    label="Training loss"
)

plt.plot(
    history_df["epoch"],
    history_df["val_loss"],
    label="Validation loss"
)

plt.xlabel("Epoch")
plt.ylabel("MSE on log realized variance")
plt.title("GRU Training and Validation Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    history_df["epoch"],
    history_df["mae"],
    label="Training MAE"
)

plt.plot(
    history_df["epoch"],
    history_df["val_mae"],
    label="Validation MAE"
)

plt.xlabel("Epoch")
plt.ylabel("MAE on log realized variance")
plt.title("GRU Training and Validation MAE")
plt.legend()
plt.show()

# %%
gru_pred_log_rv = (
    gru_model.predict(
        X_val,
        batch_size=32,
        verbose=0
    )
    .reshape(-1)
)

gru_pred_rv = np.exp(
    gru_pred_log_rv
)

actual_rv = validation_metadata[
    "actual_rv"
].to_numpy()

# %%
assert len(gru_pred_rv) == len(actual_rv)
assert np.isfinite(gru_pred_log_rv).all()
assert np.isfinite(gru_pred_rv).all()
assert (gru_pred_rv > 0).all()

print("Prediction checks passed.")
# Out:
# Prediction checks passed.

# %%
def mean_absolute_error(
    y_true,
    y_pred
):
    return np.mean(
        np.abs(
            np.asarray(y_true)
            - np.asarray(y_pred)
        )
    )


def root_mean_squared_error(
    y_true,
    y_pred
):
    return np.sqrt(
        np.mean(
            (
                np.asarray(y_true)
                - np.asarray(y_pred)
            ) ** 2
        )
    )


def qlike(
    y_true,
    y_pred,
    epsilon=1e-12
):
    y_true = np.maximum(
        np.asarray(y_true),
        epsilon
    )

    y_pred = np.maximum(
        np.asarray(y_pred),
        epsilon
    )

    ratio = y_true / y_pred

    return np.mean(
        ratio
        - np.log(ratio)
        - 1
    )


def evaluate_forecast(
    model_name,
    y_true,
    y_pred
):
    return {
        "model": model_name,
        "mae": mean_absolute_error(
            y_true,
            y_pred
        ),
        "rmse": root_mean_squared_error(
            y_true,
            y_pred
        ),
        "qlike": qlike(
            y_true,
            y_pred
        ),
    }

# %%
model_name = (
    f"GRU-{LOOKBACK_DAYS}d"
)

gru_result = evaluate_forecast(
    model_name=model_name,
    y_true=actual_rv,
    y_pred=gru_pred_rv
)

gru_result
# Out:
# {'model': 'GRU-30d',
#  'mae': np.float64(0.00039375974536247805),
#  'rmse': np.float64(0.0008638981461099693),
#  'qlike': np.float64(0.32598934619142844)}

# %%
baseline_results_df = pd.read_csv(
    shared_project_dir
    / "results"
    / "BTCUSDT"
    / "baseline_validation_metrics.csv"
)

# %%
mlp_results_df = pd.read_csv(
    shared_project_dir
    / "results"
    / "BTCUSDT"
    / "MLP"
    / "mlp_validation_metrics.csv"
)

# %%
comparison_df = pd.concat(
    [
        baseline_results_df,
        mlp_results_df,
        pd.DataFrame([gru_result]),
    ],
    ignore_index=True
)

comparison_df = (
    comparison_df
    .drop_duplicates(
        subset=["model"],
        keep="last"
    )
    .sort_values("qlike")
    .reset_index(drop=True)
)

comparison_df
# Out:
#             model       mae      rmse     qlike
# 0         GRU-30d  0.000394  0.000864  0.325989
# 1   7-Day Mean RV  0.000455  0.000899  0.343857
# 2             MLP  0.000489  0.000972  0.392329
# 3  30-Day Mean RV  0.000483  0.000921  0.399752
# 4     Persistence  0.000514  0.001087  0.464700

# %%
gru_predictions_df = (
    validation_metadata[
        [
            "symbol",
            "sequence_start_date",
            "sequence_end_date",
            "target_date",
            "actual_rv",
        ]
    ]
    .copy()
)

gru_predictions_df[
    "actual_log_rv"
] = y_val

gru_predictions_df[
    "gru_pred_log_rv"
] = gru_pred_log_rv

gru_predictions_df[
    "gru_pred_rv"
] = gru_pred_rv

# %%
history_df.to_csv(
    results_dir
    / "gru_training_history.csv",
    index=False
)

pd.DataFrame([gru_result]).to_csv(
    results_dir
    / "gru_validation_metrics.csv",
    index=False
)

comparison_df.to_csv(
    results_dir
    / "gru_model_comparison.csv",
    index=False
)

gru_predictions_df.to_parquet(
    results_dir
    / "gru_validation_predictions.parquet",
    index=False
)

gru_model.save(
    models_dir
    / "final_gru_model.keras"
)

# %%
plt.figure(figsize=(14, 5))

plt.plot(
    gru_predictions_df["target_date"],
    gru_predictions_df["actual_rv"],
    label="Actual RV"
)

plt.plot(
    gru_predictions_df["target_date"],
    gru_predictions_df["gru_pred_rv"],
    label="GRU forecast",
    alpha=0.8
)

plt.xlabel("Target date")
plt.ylabel("Realized variance")
plt.title(
    "BTC Validation Period: "
    "Actual vs GRU Forecast"
)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 5))

plt.plot(
    gru_predictions_df["target_date"],
    gru_predictions_df["actual_log_rv"],
    label="Actual log RV"
)

plt.plot(
    gru_predictions_df["target_date"],
    gru_predictions_df["gru_pred_log_rv"],
    label="GRU forecast log RV",
    alpha=0.8
)

plt.xlabel("Target date")
plt.ylabel("Log realized variance")
plt.title(
    "BTC Validation Period: "
    "Actual vs GRU Forecast on Log Scale"
)

plt.legend()
plt.show()
